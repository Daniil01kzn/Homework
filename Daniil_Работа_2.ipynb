# %% [markdown]
# <a href="https://colab.research.google.com/github/Daniil01kzn/Homework/blob/main/Daniil_%D0%A0%D0%B0%D0%B1%D0%BE%D1%82%D0%B0_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#1
import math
x = float(input('x='))
y = 0
if x>-4:
  y = math.cos(2*x)+9
else:
  y=-(math.cos(x))/(x-9)
print (y)
# Out:
# x=1
# 8.583853163452858

# %%
#2
a = float(input('a=')) # установленная норма, мин.
b = float(input('b=')) # плата за разговоры в пределах установленной нормы, руб.
c = float(input('c=')) # плата за разговоры свыше установленной нормы, руб/мин.
y = float(input('y=')) # фактическое количество минут разговоров, мин.
x = 0 # общая плата за разговоры в месяц, руб.
if y<a:
  x = b
else:
  x = b + (y-a)*c
print (x)
# Out:
# a=10
# b=560
# c=75
# y=99
# 7235.0

# %%
a = float(input('установленная норма, мин ='))
b = float(input('плата за разговоры в пределах установленной нормы, руб ='))
c = float(input('плата за разговоры свыше установленной нормы, руб/мин.='))
y = float(input('фактическое количество минут разговоров, мин='))
x = 0
if y<a:
  x = b
else:
  x = b + (y-a)*c
print ('общая плата за разговоры в месяц, руб.=')
print (x)
# Out:
# установленная норма, мин =10
# плата за разговоры в пределах установленной нормы, руб =560
# плата за разговоры свыше установленной нормы, руб/мин.=75
# фактическое количество минут разговоров, мин=99
# общая плата за разговоры в месяц, руб.=
# 7235.0

# %%
#3
a = float(input('a='))
b = float(input('b='))
c = float(input('c='))
d = float(input('d='))
if a==b and b==c:
  print (d)
if c==b and b==d:
  print (a)
if a==b and b==d:
  print (c)
if a==c and c==d:
  print (b)
# Out:
# a=95
# b=95
# c=95
# d=-1
# -1.0

# %%
#4 (a)
a = float(input('a='))
s = a%10 + a//10
if s>9 and s<100:
  print ('сумма цифр числа а =', s)
else:
  print ('сумма цифр а не является двухзначным числом')
# Out:
# a=67
# сумма цифр числа а = 13.0

# %%
#4 (b)
a = float(input('a='))
s = a%10 + a//10
if s>a:
  print ('число а меньше суммы его цифр')
else:
  print ('число а больше суммы его цифр')
# Out:
# a=98
# число а больше суммы его цифр

# %%
#5 (a)
a = float(input('a='))
b = float(input('b='))
c = float(input('c='))
d = float(input('d='))
a <= 8 and b <= 8 and c <= 8 and d<= 8
if a%2 == b%2 and c%2 == d%2:
  print ('белая фигура попадет под удар чёрной')
else:
  if a%2 != b%2 and c%2 != d%2:
    print ('белая фигура попадет под удар чёрной')
  else:
    print ('белая фигура не попадет под удар чёрной')
# Out:
# a=5
# b=4
# c=3
# d=6
# белая фигура попадет под удар чёрной

# %%
#5 (a)
a = float(input('a='))
b = float(input('b='))
c = float(input('c='))
d = float(input('d='))
e = float(input('e='))
f = float(input('f='))
x1 = abs(a-c)
x2 = abs(b-f)
x3 = abs(c-e)
x4 = abs(d-f)
a <= 8 and b <= 8 and c <= 8 and d<= 8 and e <= 8 and f<= 8 and x1 == x2 and x1<= 8 and x2 <=8
if x3 == x4 and x3 <= 8 and x4 <= 8:
  print ('белая фигура попадет под удар чёрной')
else:
  print ('белая фигура не попадет под удар чёрной')
# Out:
# a=4
# b=6
# c=3
# d=3
# e=5
# f=5
# белая фигура попадет под удар чёрной

# %%
#5 (b)
a = float(input('a='))
b = float(input('b='))
c = float(input('c='))
d = float(input('d='))
e = float(input('e='))
f = float(input('f='))
x1 = abs(a-c)
x2 = abs(b-f)
x3 = abs(c-e)
x4 = abs(d-f)
a <= 8 and b <= 8 and c <= 8 and d<= 8 and e <= 8 and f<= 8 and x1 == x2 and x1<= 8 and x2 <=8
if (x3 == x4 and x3 <= 8 and x4 <= 8) or e == c or f == d:
  print ('белая фигура попадет под удар чёрной')
else:
  print ('белая фигура не попадет под удар чёрной')
# Out:
# a=4
# b=6
# c=3
# d=3
# e=7
# f=3
# белая фигура попадет под удар чёрной

# %%
#5 (с)
a = float(input('a='))
b = float(input('b='))
c = float(input('c='))
d = float(input('d='))
e = float(input('e='))
f = float(input('f='))
x1 = abs(a-c)
x2 = abs(b-f)
x3 = abs(c-e)
x4 = abs(d-f)
a <= 8 and b <= 8 and c <= 8 and d<= 8 and e <= 8 and f<= 8 and x1 == x2 and x1<= 8 and x2 <=8
if (x3 == 2 and x4 == 1) or (x3 == 1 and x4 == 2):
  print ('белая фигура попадет под удар чёрной')
else:
  print ('белая фигура не попадет под удар чёрной')
# Out:
# a=4
# b=5
# c=3
# d=3
# e=5
# f=4
# белая фигура попадет под удар чёрной
