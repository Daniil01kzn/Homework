# %% [markdown]
# <a href="https://colab.research.google.com/github/Daniil01kzn/Homework/blob/main/%D0%A0%D0%B0%D0%B1%D0%BE%D1%82%D0%B0_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
'№1'
x = int(input('x='))
t = ((x*(1-x)+x*(x**2-1))/(8*x**2))
print (t)
# Out:
# x=23
# 769562.75

# %%
'№2'
import math
x = int(input('x='))
w = math.log(math.sqrt(x-5))+math.log(math.sqrt(2*x-3))
print (w)
# Out:
# x=23
# 3.3257859367948637

# %%
'№3'
import math
a = math.pi
b = math.pi**2
c = math.pi**3
d = math.pi**4
print (a,b,c,d, sep='\n')
# Out:
# 3.141592653589793
# 9.869604401089358
# 31.006276680299816
# 97.40909103400242

# %%
'№4'
N = float(input('N='))
s = N%3600
print (s)
# Out:
# N=4000
# 400.0

# %%
'№5'
a = int(input('a='))
b = int (input('b='))
c = a%2
d = b%2
y = c!=d
print (y)
# Out:
# a=56
# b=66
# False
