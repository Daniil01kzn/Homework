# %% [markdown]
# <a href="https://colab.research.google.com/github/Daniil01kzn/Homework/blob/main/_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#1
x = 64
y1 = 4
y2 = 2
s1 = 0
s2 = 0
for i in range (0, x//y1):
  x = x-i*y1
  s1 = i
  s2 = x//y2
  print (s1, s2)
# Out:
# 0 32
# 1 30
# 2 26
# 3 20
# 4 12
# 5 2
# 6 -10
# 7 -24
# 8 -40
# 9 -58
# 10 -78
# 11 -100
# 12 -124
# 13 -150
# 14 -178
# 15 -208

# %%
#2
import math
x = float(input('x='))
y = x
for i in range (1,14,2):
  y = (x**i)/math.factorial(i)-(x**i)/math.factorial(i)

print (y)
# Out:
# x=2
# 1.9999986844431288

# %%
#3

# %%
#4

# %%
#5

# %%
x = 15
p = 0.13
k = 1
s = 0
while k<=18:
  x = x+x*p
  s = s+x
  k = k+1

print (x, s)
# Out:
# 135.36401947752424 1046.2410923815564

# %%
import math
N = int(input('N='))
y = 1/math.cos(1)
k = math.cos(1)
for i in range (2,N+1):
  k = k+math.cos(i)
  y = y+(1/(k))
print (y)
# Out:
# N=5
# 7.282981638940141
